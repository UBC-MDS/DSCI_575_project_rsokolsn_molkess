# %% [markdown]
# # Milestone 2: RAG Pipelines

# %% [markdown]
# ## All 10 queries
#
# RAG for each query is done in the script `results/run_queries.py`

# %%
import pandas as pd

# %%
queries = pd.read_csv('../results/queries.csv', usecols=['query', 'difficulty', 'type', 'hybrid rag'])
queries
# Out:
#                                                query difficulty  \
# 0                                       harry potter       Easy
# 1                  learn python programming beginner       Easy
# 2          overcoming grief after losing a loved one     Medium
# 3  self-help book for managing anxiety and stress...     Medium
# 4  historical novel about World War 2 from a civi...       Hard
# 5                          stephen king horror novel       Easy
# 6         romance novel with enemies to lovers trope     Medium
# 7  a story about a young person finding their ide...     Medium
# 8  mystery thriller with unreliable narrator set ...       Hard
# 9  best science fiction book for someone who like...       Hard
#
#               type                                         hybrid rag
# 0          Keyword  Based on the provided context, here are some b...
# 1          Keyword  Based on the Amazon dataset, I would recommend...
# 2         Semantic  Based on the provided Amazon dataset, I recomm...
# 3         Semantic  Based on the provided Amazon dataset, I recomm...
# 4  Multi-attribute  Based on your request for a historical novel a...
# 5          Keyword  Based on the Amazon dataset, I recommend the f...
# 6          Keyword  Based on the Amazon dataset, I recommend the f...
# 7         Semantic  Based on the provided context, here are some b...
# 8  Multi-attribute  Based on the Amazon dataset, I would recommend...
# 9  Multi-attribute  Based on the provided Amazon dataset, I recomm...

# %%
for _, row in queries.iterrows():
    print(f'Query: {row['query']}')
    print(f'Difficulty: {row['difficulty']}, Query Type: {row['type']}')
    print(f'RAG response: {row['hybrid rag']}')
    print('\n')
# Out:
# Query: harry potter
# Difficulty: Easy, Query Type: Keyword
# RAG response: Based on the provided context, here are some book recommendations related to Harry Potter:
#
# 1. **Harry Potter Film Wizardry (Arabic Edition)** by Brian Sibley: This book is a great choice for fans who want to explore the behind-the-scenes magic of the Harry Potter films.
# 2. **Harry Potter: The Dark Arts (Tiny Book)** by Insight Editions: This collectible art book features facts and art from the Harry Potter films, and is a great addition to any fan's collection.
# 3. **Complete 1-st Edition Harry Potter Full Book Set Volumes 1-7 Hardback** by J.K. Rowling: If you're looking to collect the entire series, this hardback set is a great option.
# 4. **Harry Potter y el legado maldito / Harry Potter and the Cursed Child (Spanish Edition)** by J.K. Rowling: This play script is a great addition to any fan's collection, and explores the story of Harry's son Albus.
# 5. **Fantastic Beasts and Where to Find Them** by J.K. Rowling: This companion book to the Harry Potter series explores the magical creatures of the wizarding world.
#
#
# Query: learn python programming beginner
# Difficulty: Easy, Query Type: Keyword
# RAG response: Based on the Amazon dataset, I would recommend the following books for learning Python programming as a beginner:
#
# 1. **"101 Extra Python Challenges with Solutions / Code Listings"** by  - This book provides a comprehensive collection of 101 Python challenges that help you develop and apply your programming skills. The book is well-structured and organized into ten chapters, making it easy to follow and understand.
#
# 2. **"40 Algorithms Every Programmer Should Know: Hone your problem-solving skills by learning different algorithms and their implementation in Python"** by Imran Ahmad - This book is a great resource for beginners who want to learn algorithms and data structures in Python. It covers a wide range of topics, from fundamental algorithms to machine learning and cryptography.
#
# Both of these books are highly rated (4.5 and 4.3 respectively) and are suitable for beginners. They provide a solid foundation in Python programming and will help you develop your problem-solving skills.
#
#
# Query: overcoming grief after losing a loved one
# Difficulty: Medium, Query Type: Semantic
# RAG response: Based on the provided Amazon dataset, I recommend the following books for overcoming grief after losing a loved one:
#
# 1. **Anatomy of Grief: An Inspirational Guide to Surviving the Death of Your Child** by Barbara Repczynski (5.0 rating) - This book chronicles the author's personal journey of coping with the loss of a child and offers practical advice on how to move forward.
# 2. **30 Days toward Healing Your Grief: A Workbook for Healing** by Danielle Morris (4.4 rating) - This workbook offers a Christ-centered approach to healing from loss, providing daily reflections and inspirational stories to help readers navigate their grief.
# 3. **I'm Grieving as Fast as I Can: How Young Widows and Widowers Can Cope and Heal** by Linda Sones Feinberg (4.5 rating) - This book provides a guide for young widows and widowers, addressing the unique challenges they face in coping with the loss of a spouse.
# 4. **Gravity's Embrace: A True Unsolved Mystery Surrounding An Alaskan Pilot** by Cynthia Young Fackrell (4.6 rating) - While not exclusively focused on grief, this book explores the heartache of a missing loved one and offers a powerful story of hope and resilience.
#
# These books offer a range of perspectives and approaches to coping with grief, and may be helpful for individuals seeking guidance and support after losing a loved one.
#
#
# Query: self-help book for managing anxiety and stress at work
# Difficulty: Medium, Query Type: Semantic
# RAG response: Based on the provided Amazon dataset, I recommend the following self-help books for managing anxiety and stress at work:
#
# 1. **Emotional Core Therapy** by Robert A. Moylan: This book focuses on understanding and processing emotions to achieve emotional balance and reduce stress. The author provides a step-by-step process to help readers manage relationship stress and achieve inner peace.
# 2. **Cognitive Behavioral Therapy: A Psychologist's Guide to Overcome Anxiety, Depression, & Negative Thought Patterns** by [Author Not Available]: Although the author is not listed, this book on cognitive behavioral therapy can help readers overcome anxiety, depression, and negative thought patterns, which can be highly relevant to managing stress at work.
# 3. **The Art of Calm: Relaxation Through the Five Senses** by Brian Luke Seaward: While this book is not specifically focused on work-related stress, it offers practical tips and strategies for achieving calm and relaxation, which can be applied to managing anxiety and stress in the workplace.
#
# Please note that the dataset does not provide information about the specific work-related stress management books.
#
#
# Query: historical novel about World War 2 from a civilian perspective
# Difficulty: Hard, Query Type: Multi-attribute
# RAG response: Based on your request for a historical novel about World War 2 from a civilian perspective, I recommend the following books:
#
# 1. **BBC History Magazine: The Second World War Story** - This book offers a comprehensive and engaging account of World War 2 from a British perspective, providing a unique civilian view of the war.
# 2. **A High and Hidden Place: A Novel** by Michele Claire Lucas - This novel tells the story of Christine Lenoir, a young woman who embarks on a journey to uncover the truth about her family's past and the horrors they experienced during World War 2. The book offers a powerful and emotional account of the war from a civilian perspective.
#
# Both of these books are highly rated and offer a compelling and thought-provoking reading experience.
#
#
# Query: stephen king horror novel
# Difficulty: Easy, Query Type: Keyword
# RAG response: Based on the Amazon dataset, I recommend the following Stephen King horror novels:
#
# 1. **Thinner** (4.5/5) - A #1 national bestseller about a man who becomes emaciated after being cursed by an ancient father.
# 2. **The Green Mile** (4.8/5) - A serial novel about a death house in a Southern prison, featuring a charming narrator and a mix of horror and drama.
#
# Both of these novels are highly rated and well-loved by fans of the horror genre.
#
#
# Query: romance novel with enemies to lovers trope
# Difficulty: Medium, Query Type: Keyword
# RAG response: Based on the Amazon dataset, I recommend the following romance novels with the enemies-to-lovers trope:
#
# 1. **Letting Love Win** by Alysia S. Knight (Rating: 4.1) - This romance novel features a good vs. evil theme, which might fit the enemies-to-lovers trope.
# 2. **Reign Returned: The Felserpent Chronicles** by Katie Keridan (Rating: 4.7) - This young adult fantasy novel features a romance between two characters from different realms, which might involve an enemies-to-lovers dynamic.
# 3. **A Rose in Winter** by Kathleen E. Woodiwiss (Rating: 4.7) - Although the description doesn't explicitly mention the enemies-to-lovers trope, the romance novel has a strong focus on the relationship between the two main characters, which might involve an adversarial or conflicting past.
#
# These recommendations are based on the information available in the Amazon dataset.
#
#
# Query: a story about a young person finding their identity
# Difficulty: Medium, Query Type: Semantic
# RAG response: Based on the provided context, here are some book recommendations that fit the theme of a young person finding their identity:
#
# 1. **That Guy in Our Women's Studies Class** by Allan D. Hunter: This memoir explores the complexities of intersectionality and the interconnected nature of social categorizations, including gender, race, and class. It's a story of self-discovery and empowerment, making it a great fit for readers looking for a story about identity.
#
# 2. **Camp** by Lev AC Rosen: This novel follows Randy, a young person who reinvents himself to fit into a more traditional mold of masculinity. As Randy navigates his relationships and identity, he must confront the question of how much he's willing to change for love. This book is a great exploration of identity, self-acceptance, and the complexities of human relationships.
#
# 3. **Holding the Light; A Soldier's Journey**: While not explicitly focused on identity, this picture book follows a young person who loses their way but finds it again by recognizing a higher purpose for their life. It's a story of resilience, hope, and self-discovery that may appeal to readers looking for a story about a young person finding their identity.
#
# These recommendations are based on the provided context and may not be exhaustive, but they should provide a good starting point for readers looking for stories about young people finding their identity.
#
#
# Query: mystery thriller with unreliable narrator set in small town
# Difficulty: Hard, Query Type: Multi-attribute
# RAG response: Based on the Amazon dataset, I would recommend the following books:
#
# 1. **A Legacy of Lies: A Rock Ridge Mystery**: This book features a small town setting and an engaging mystery that unravels the dark secrets of the town's past. The story has complex characters, and the narrator's perspective might be unreliable, adding to the thriller element.
# 2. **Guilty by Association**: This psychological thriller is set in a small town, where the police department is involved in a secret agreement with the Japanese mafia. The story features a dangerous game of cat-and-mouse, and the narrator's reliability is questionable.
#
#
# Query: best science fiction book for someone who liked The Martian
# Difficulty: Hard, Query Type: Multi-attribute
# RAG response: Based on the provided Amazon dataset, I recommend the following science fiction books:
#
# 1. **Old Man's War Boxed Set I: Old Man's War, The Ghost Brigades, The Last Colony** by John Scalzi: This series is a great fit for fans of The Martian, as it combines space exploration, adventure, and thought-provoking themes.
#
# 2. **REVOLT OF THE GALAXY (Family d'Alembert series #10)** by Stephen Goldin: While not directly related to The Martian, this book is part of a series that explores the galaxy and interstellar politics, which might appeal to fans of The Martian's blend of science, adventure, and human connection.
#
# 3. **Transit to Scorpio** by Alan Burt Akers: This book is part of the Dray Prescot series, which shares some similarities with The Martian in its planetary adventures and light-hearted tone.
#
# All of these recommendations are science fiction books with a space-faring theme, making them suitable for fans of The Martian.

# %% [markdown]
# ### Manual Evaluation of RAG output
# |query | Accuracy | Completeness | Fluency|
# |----------|----------|----------|-------|
# | harry potter  | yes   | yes   |no|
# | learn python programming beginner  | no  | no   |yes|
# | overcoming grief after losing a loved one | yes  | yes   |yes|
# | self-help book for managing anxiety and stress at work | yes  | yes   |yes|
# | historical novel about World War 2 from a civilian perspective | yes  | yes   |yes|
# | stephen king horror novel | yes | yes | yes |
# | romance novel with enemies to lovers trope | yes  | no   |yes|
# |a story about a young person finding their identity| yes | yes | yes|
# | mystery thriller with unreliable narrator set in small town | yes | yes | yes|
# | best science fiction book for someone who liked The Martian | yes | yes | yes|
